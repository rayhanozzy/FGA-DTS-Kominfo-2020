# %% [markdown]
# Import the Library

# %%
#from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %% [markdown]
# Import the data set and analyze it.

# %%
#q1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Bikeshare 2017/Bikeshare Ridership (2017 Q1).csv')
#q2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Bikeshare 2017/Bikeshare Ridership (2017 Q2).csv')
#q3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Bikeshare 2017/Bikeshare Ridership (2017 Q3).csv')
#q4 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Bikeshare 2017/Bikeshare Ridership (2017 Q4).csv')

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_1072d4c063164370a50a918430413880 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='dI3tJSJbm6qzDzVhirVofNikyMBsfPNkE34FROriwB4L',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q1).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q1 = pd.read_csv(body)
q1.head()
# Out:
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0   712382   1/1/2017 0:00  1/1/2017 0:03                    223
# 1   712383   1/1/2017 0:00  1/1/2017 0:05                    279
# 2   712384   1/1/2017 0:05  1/1/2017 0:29                   1394
# 3   712385   1/1/2017 0:07  1/1/2017 0:21                    826
# 4   712386   1/1/2017 0:08  1/1/2017 0:12                    279
#
#    from_station_id                  from_station_name  to_station_id  \
# 0             7051  Wellesley St E / Yonge St Green P           7089
# 1             7143           Kendal Ave / Bernard Ave           7154
# 2             7113       Parliament St / Aberdeen Ave           7199
# 3             7077                 College Park South           7010
# 4             7079              McGill St / Church St           7047
#
#                  to_station_name user_type
# 0           Church St  / Wood St    Member
# 1        Bathurst Subway Station    Member
# 2      College St W / Markham St    Member
# 3        King St W / Spadina Ave    Member
# 4  University Ave / Gerrard St W    Member

# %%
body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q2).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q2 = pd.read_csv(body)
q2.head()
# Out:
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0   868665   1/4/2017 0:01  1/4/2017 0:06                  297.0
# 1   868666   1/4/2017 0:07  1/4/2017 0:11                  236.0
# 2   868667   1/4/2017 0:08  1/4/2017 0:14                  380.0
# 3   868668   1/4/2017 0:12  1/4/2017 0:34                 1299.0
# 4   868669   1/4/2017 0:13  1/4/2017 0:18                  323.0
#
#    from_station_id                        from_station_name  to_station_id  \
# 0           7073.0               Bremner Blvd / Spadina Ave         7211.0
# 1           7038.0                     Dundas St / Yonge St         7163.0
# 2           7012.0  Elizabeth St / Edward St (Bus Terminal)         7069.0
# 3           7172.0             Strachan Ave / Princes' Blvd         7069.0
# 4           7039.0                  Simcoe St / Dundas St W         7021.0
#
#                 to_station_name user_type
# 0  Fort York Blvd / Garrison Rd    Member
# 1            Yonge St / Wood St    Member
# 2      Queen St W / Spadina Ave    Member
# 3      Queen St W / Spadina Ave    Member
# 4            Bay St / Albert St    Member

# %%
body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q3).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q3 = pd.read_csv(body)
q3.head()
# Out:
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0  1253914   7/1/2017 0:00  7/1/2017 0:15                    910
# 1  1253915   7/1/2017 0:01  7/1/2017 0:15                    837
# 2  1253916   7/1/2017 0:01  7/1/2017 0:14                    786
# 3  1253917   7/1/2017 0:01  7/1/2017 0:25                   1420
# 4  1253918   7/1/2017 0:01  7/1/2017 0:25                   1437
#
#                          from_station_name           to_station_name user_type
# 0              Princess St / Adelaide St E       424 Wellington St W    Member
# 1            Fort York  Blvd / Capreol Crt  HTO Park (Queens Quay W)    Casual
# 2            Fort York  Blvd / Capreol Crt  HTO Park (Queens Quay W)    Casual
# 3  Elizabeth St / Edward St (Bus Terminal)   Boston Ave / Queen St E    Casual
# 4  Elizabeth St / Edward St (Bus Terminal)   Boston Ave / Queen St E    Casual

# %%
body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q4).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q4 = pd.read_csv(body)
q4.head()
# Out:
#    trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0  1971685  10/01/17 00:00:01  10/01/17 00:14:10                    849
# 1  1971686  10/01/17 00:00:01  10/01/17 00:00:27                     26
# 2  1971687  10/01/17 00:00:22  10/01/17 00:22:12                   1310
# 3  1971688  10/01/17 00:00:38  10/01/17 00:11:09                    631
# 4  1971689  10/01/17 00:00:55  10/01/17 00:20:53                   1198
#
#                      from_station_name                      to_station_name  \
# 0                Queen St W / James St                    Taddle Creek Park
# 1    Stewart St / Bathurst St  - SMART    Stewart St / Bathurst St  - SMART
# 2             Hayter St / Laplante Ave             Queen St W / Portland St
# 3              Beverly St / College St            Beverly  St / Dundas St W
# 4  Thompson St / Broadview Ave - SMART  Thompson St / Broadview Ave - SMART
#
#   user_type
# 0    Member
# 1    Casual
# 2    Member
# 3    Member
# 4    Member

# %%
display(q1.head())
display(q2.head())
display(q3.head())
display(q4.head())
# Out:
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0   712382   1/1/2017 0:00  1/1/2017 0:03                    223
# 1   712383   1/1/2017 0:00  1/1/2017 0:05                    279
# 2   712384   1/1/2017 0:05  1/1/2017 0:29                   1394
# 3   712385   1/1/2017 0:07  1/1/2017 0:21                    826
# 4   712386   1/1/2017 0:08  1/1/2017 0:12                    279
#
#    from_station_id                  from_station_name  to_station_id  \
# 0             7051  Wellesley St E / Yonge St Green P           7089
# 1             7143           Kendal Ave / Bernard Ave           7154
# 2             7113       Parliament St / Aberdeen Ave           7199
# 3             7077                 College Park South           7010
# 4             7079              McGill St / Church St           7047
#
#                  to_station_name user_type
# 0           Church St  / Wood St    Member
# 1        Bathurst Subway Station    Member
# 2      College St W / Markham St    Member
# 3        King St W / Spadina Ave    Member
# 4  University Ave / Gerrard St W    Member
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0   868665   1/4/2017 0:01  1/4/2017 0:06                  297.0
# 1   868666   1/4/2017 0:07  1/4/2017 0:11                  236.0
# 2   868667   1/4/2017 0:08  1/4/2017 0:14                  380.0
# 3   868668   1/4/2017 0:12  1/4/2017 0:34                 1299.0
# 4   868669   1/4/2017 0:13  1/4/2017 0:18                  323.0
#
#    from_station_id                        from_station_name  to_station_id  \
# 0           7073.0               Bremner Blvd / Spadina Ave         7211.0
# 1           7038.0                     Dundas St / Yonge St         7163.0
# 2           7012.0  Elizabeth St / Edward St (Bus Terminal)         7069.0
# 3           7172.0             Strachan Ave / Princes' Blvd         7069.0
# 4           7039.0                  Simcoe St / Dundas St W         7021.0
#
#                 to_station_name user_type
# 0  Fort York Blvd / Garrison Rd    Member
# 1            Yonge St / Wood St    Member
# 2      Queen St W / Spadina Ave    Member
# 3      Queen St W / Spadina Ave    Member
# 4            Bay St / Albert St    Member
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0  1253914   7/1/2017 0:00  7/1/2017 0:15                    910
# 1  1253915   7/1/2017 0:01  7/1/2017 0:15                    837
# 2  1253916   7/1/2017 0:01  7/1/2017 0:14                    786
# 3  1253917   7/1/2017 0:01  7/1/2017 0:25                   1420
# 4  1253918   7/1/2017 0:01  7/1/2017 0:25                   1437
#
#                          from_station_name           to_station_name user_type
# 0              Princess St / Adelaide St E       424 Wellington St W    Member
# 1            Fort York  Blvd / Capreol Crt  HTO Park (Queens Quay W)    Casual
# 2            Fort York  Blvd / Capreol Crt  HTO Park (Queens Quay W)    Casual
# 3  Elizabeth St / Edward St (Bus Terminal)   Boston Ave / Queen St E    Casual
# 4  Elizabeth St / Edward St (Bus Terminal)   Boston Ave / Queen St E    Casual
#    trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0  1971685  10/01/17 00:00:01  10/01/17 00:14:10                    849
# 1  1971686  10/01/17 00:00:01  10/01/17 00:00:27                     26
# 2  1971687  10/01/17 00:00:22  10/01/17 00:22:12                   1310
# 3  1971688  10/01/17 00:00:38  10/01/17 00:11:09                    631
# 4  1971689  10/01/17 00:00:55  10/01/17 00:20:53                   1198
#
#                      from_station_name                      to_station_name  \
# 0                Queen St W / James St                    Taddle Creek Park
# 1    Stewart St / Bathurst St  - SMART    Stewart St / Bathurst St  - SMART
# 2             Hayter St / Laplante Ave             Queen St W / Portland St
# 3              Beverly St / College St            Beverly  St / Dundas St W
# 4  Thompson St / Broadview Ave - SMART  Thompson St / Broadview Ave - SMART
#
#   user_type
# 0    Member
# 1    Casual
# 2    Member
# 3    Member
# 4    Member

# %% [markdown]
# the columns of each data were different, so we have to check the shape of each data set.

# %%
print(q1.shape)
print(q2.shape)
print(q3.shape)
print(q4.shape)
# Out:
# (132123, 9)
# (196152, 9)
# (663488, 7)
# (363405, 7)

# %% [markdown]
# As you can see, q1 and q2 data set have the same number of columns. so was q3 and q4 data set. but q1,q2 and q3,q4 have different number of columns. so we will concatenate q1 and q2. then we will concatenate q3 and q4 also.

# %%
bikeshare2017_1 = pd.concat([q1,q1],join='outer')
bikeshare2017_2 = pd.concat([q3,q4],join='outer')
display(bikeshare2017_1)
display(bikeshare2017_2)
# Out:
#         trip_id   trip_start_time    trip_stop_time  trip_duration_seconds  \
# 0        712382     1/1/2017 0:00     1/1/2017 0:03                    223
# 1        712383     1/1/2017 0:00     1/1/2017 0:05                    279
# 2        712384     1/1/2017 0:05     1/1/2017 0:29                   1394
# 3        712385     1/1/2017 0:07     1/1/2017 0:21                    826
# 4        712386     1/1/2017 0:08     1/1/2017 0:12                    279
# ...         ...               ...               ...                    ...
# 132118   868705  31/03/2017 23:49     1/4/2017 0:09                   1222
# 132119   868661  31/03/2017 23:49  31/03/2017 23:57                    489
# 132120   868662  31/03/2017 23:49  31/03/2017 23:57                    442
# 132121   868663  31/03/2017 23:52     1/4/2017 0:10                   1116
# 132122   868664  31/03/2017 23:54  31/03/2017 23:56                    155
#
#         from_station_id                           from_station_name  \
# 0                  7051           Wellesley St E / Yonge St Green P
# 1                  7143                    Kendal Ave / Bernard Ave
# 2                  7113                Parliament St / Aberdeen Ave
# 3                  7077                          College Park South
# 4                  7079                       McGill St / Church St
# ...                 ...                                         ...
# 132118             7029                         Bay St / Bloor St W
# 132119             7006             Bay St / College St (East Side)
# 132120             7006             Bay St / College St (East Side)
# 132121             7057                 Simcoe St / Wellington St W
# 132122             7014  Sherbourne St / Carlton St (Allan Gardens)
#
#         to_station_id                to_station_name user_type
# 0                7089           Church St  / Wood St    Member
# 1                7154        Bathurst Subway Station    Member
# 2                7199      College St W / Markham St    Member
# 3                7010        King St W / Spadina Ave    Member
# 4                7047  University Ave / Gerrard St W    Member
# ...               ...                            ...       ...
# 132118           7017       Widmer St / Adelaide St     Member
# 132119           7066   Willcocks St / St. George St    Member
# 132120           7066   Willcocks St / St. George St    Member
# 132121           7023       College St W / Borden St    Member
# 132122           7113   Parliament St / Aberdeen Ave    Member
#
# [264246 rows x 9 columns]
#         trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0       1253914      7/1/2017 0:00      7/1/2017 0:15                    910
# 1       1253915      7/1/2017 0:01      7/1/2017 0:15                    837
# 2       1253916      7/1/2017 0:01      7/1/2017 0:14                    786
# 3       1253917      7/1/2017 0:01      7/1/2017 0:25                   1420
# 4       1253918      7/1/2017 0:01      7/1/2017 0:25                   1437
# ...         ...                ...                ...                    ...
# 363400  2383642  12/31/17 23:46:27  12/31/17 23:46:53                     26
# 363401  2383643  12/31/17 23:47:13   1/01/18 00:11:40                   1467
# 363402  2383644  12/31/17 23:47:40  12/31/17 23:57:49                    609
# 363403  2383645  12/31/17 23:49:08  12/31/17 23:49:34                     26
# 363404  2383646  12/31/17 23:49:41  12/31/17 23:57:41                    480
#
#                               from_station_name           to_station_name  \
# 0                   Princess St / Adelaide St E       424 Wellington St W
# 1                 Fort York  Blvd / Capreol Crt  HTO Park (Queens Quay W)
# 2                 Fort York  Blvd / Capreol Crt  HTO Park (Queens Quay W)
# 3       Elizabeth St / Edward St (Bus Terminal)   Boston Ave / Queen St E
# 4       Elizabeth St / Edward St (Bus Terminal)   Boston Ave / Queen St E
# ...                                         ...                       ...
# 363400                 Bloor St / Brunswick Ave  Bloor St / Brunswick Ave
# 363401                 Bloor St / Brunswick Ave  HTO Park (Queens Quay W)
# 363402                  Kendal Ave / Spadina Rd  Augusta Ave / Denison Sq
# 363403                  Phoebe St / Spadina Ave   Phoebe St / Spadina Ave
# 363404                  Phoebe St / Spadina Ave    Simcoe St / Queen St W
#
#        user_type
# 0         Member
# 1         Casual
# 2         Casual
# 3         Casual
# 4         Casual
# ...          ...
# 363400    Casual
# 363401    Casual
# 363402    Member
# 363403    Member
# 363404    Member
#
# [1026893 rows x 7 columns]

# %% [markdown]
# > Question No.1  : Find out what percentage of bikes are
# returned to its initial location?

# %% [markdown]
# We will find if the bikes were returned to it's initial location using from_station_id, to_station_id, from_station_name and to_station_name feature in each data set. if each feature is common, so the bikes were returned to it's initial location.

# %%
bike_returned_2017_1 = bikeshare2017_1.loc[bikeshare2017_1['from_station_id']==bikeshare2017_1['to_station_id']]
bike_returned_2017_2 = bikeshare2017_2.loc[bikeshare2017_2['from_station_name']==bikeshare2017_2['to_station_name']]
df1 = bike_returned_2017_1
df2 = bike_returned_2017_2
display(df1)
display(df2)
# Out:
#         trip_id   trip_start_time    trip_stop_time  trip_duration_seconds  \
# 64       712447     1/1/2017 4:15     1/1/2017 4:25                    625
# 100      712484     1/1/2017 6:42     1/1/2017 6:44                     79
# 125      712510     1/1/2017 9:57    1/1/2017 10:03                    359
# 192      712580    1/1/2017 17:03    1/1/2017 17:36                   1961
# 198      712586    1/1/2017 17:08    1/1/2017 18:36                   5295
# ...         ...               ...               ...                    ...
# 131744   868250  31/03/2017 17:04  31/03/2017 17:10                    339
# 131798   868307  31/03/2017 18:08  31/03/2017 18:21                    813
# 131814   868324  31/03/2017 18:33  31/03/2017 18:54                   1267
# 131841   868352  31/03/2017 19:13  31/03/2017 19:15                     82
# 131874   868388  31/03/2017 19:57  31/03/2017 20:15                   1058
#
#         from_station_id                        from_station_name  \
# 64                 7003                 Madison Ave / Bloor St W
# 100                7060                Princess St / Adelaide St
# 125                7100           Dundas St E / Regent Park Blvd
# 192                7018                   Bremner Blvd / Rees St
# 198                7016  Bay St / Queens Quay W (Ferry Terminal)
# ...                 ...                                      ...
# 131744             7007                  College St W / Huron St
# 131798             7022                   Simcoe St / Queen St W
# 131814             7010                  King St W / Spadina Ave
# 131841             7007                  College St W / Huron St
# 131874             7133                       Summerhill Station
#
#         to_station_id                          to_station_name user_type
# 64               7003                 Madison Ave / Bloor St W    Member
# 100              7060                Princess St / Adelaide St    Member
# 125              7100           Dundas St E / Regent Park Blvd    Member
# 192              7018                   Bremner Blvd / Rees St    Casual
# 198              7016  Bay St / Queens Quay W (Ferry Terminal)    Casual
# ...               ...                                      ...       ...
# 131744           7007                  College St W / Huron St    Member
# 131798           7022                   Simcoe St / Queen St W    Member
# 131814           7010                  King St W / Spadina Ave    Member
# 131841           7007                  College St W / Huron St    Member
# 131874           7133                       Summerhill Station    Casual
#
# [3098 rows x 9 columns]
#         trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 27      1253940      7/1/2017 0:14      7/1/2017 0:15                     66
# 31      1253945      7/1/2017 0:18      7/1/2017 1:04                   2743
# 32      1253946      7/1/2017 0:18      7/1/2017 1:03                   2718
# 33      1253947      7/1/2017 0:18      7/1/2017 1:04                   2762
# 34      1253948      7/1/2017 0:18      7/1/2017 1:04                   2747
# ...         ...                ...                ...                    ...
# 363261  2383488  12/31/17 15:44:39  12/31/17 16:47:41                   3782
# 363328  2383570  12/31/17 17:46:40  12/31/17 17:46:51                     11
# 363332  2383574  12/31/17 18:05:56  12/31/17 18:06:08                     12
# 363400  2383642  12/31/17 23:46:27  12/31/17 23:46:53                     26
# 363403  2383645  12/31/17 23:49:08  12/31/17 23:49:34                     26
#
#                       from_station_name                  to_station_name  \
# 27                        Union Station                    Union Station
# 31               Queens Quay / Yonge St           Queens Quay / Yonge St
# 32               Queens Quay / Yonge St           Queens Quay / Yonge St
# 33               Queens Quay / Yonge St           Queens Quay / Yonge St
# 34               Queens Quay / Yonge St           Queens Quay / Yonge St
# ...                                 ...                              ...
# 363261  Queens Quay W / Lower Simcoe St  Queens Quay W / Lower Simcoe St
# 363328            Queen St W / James St            Queen St W / James St
# 363332    University Ave / Gerrard St W    University Ave / Gerrard St W
# 363400         Bloor St / Brunswick Ave         Bloor St / Brunswick Ave
# 363403          Phoebe St / Spadina Ave          Phoebe St / Spadina Ave
#
#        user_type
# 27        Member
# 31        Casual
# 32        Casual
# 33        Casual
# 34        Casual
# ...          ...
# 363261    Casual
# 363328    Member
# 363332    Member
# 363400    Casual
# 363403    Member
#
# [59900 rows x 7 columns]

# %%
bike_returned_2017 = bike_returned_2017_1.shape[0] + bike_returned_2017_2.shape[0]
bike_returned_2017
# Out:
# 62998

# %%
bike_notreturned_2017_1 = bikeshare2017_1.loc[bikeshare2017_1['from_station_id']!=bikeshare2017_1['to_station_id']]
bike_notreturned_2017_2 = bikeshare2017_2.loc[bikeshare2017_2['from_station_name']!=bikeshare2017_2['to_station_name']]
display(bike_notreturned_2017_1)
display(bike_notreturned_2017_2)
# Out:
#         trip_id   trip_start_time    trip_stop_time  trip_duration_seconds  \
# 0        712382     1/1/2017 0:00     1/1/2017 0:03                    223
# 1        712383     1/1/2017 0:00     1/1/2017 0:05                    279
# 2        712384     1/1/2017 0:05     1/1/2017 0:29                   1394
# 3        712385     1/1/2017 0:07     1/1/2017 0:21                    826
# 4        712386     1/1/2017 0:08     1/1/2017 0:12                    279
# ...         ...               ...               ...                    ...
# 132118   868705  31/03/2017 23:49     1/4/2017 0:09                   1222
# 132119   868661  31/03/2017 23:49  31/03/2017 23:57                    489
# 132120   868662  31/03/2017 23:49  31/03/2017 23:57                    442
# 132121   868663  31/03/2017 23:52     1/4/2017 0:10                   1116
# 132122   868664  31/03/2017 23:54  31/03/2017 23:56                    155
#
#         from_station_id                           from_station_name  \
# 0                  7051           Wellesley St E / Yonge St Green P
# 1                  7143                    Kendal Ave / Bernard Ave
# 2                  7113                Parliament St / Aberdeen Ave
# 3                  7077                          College Park South
# 4                  7079                       McGill St / Church St
# ...                 ...                                         ...
# 132118             7029                         Bay St / Bloor St W
# 132119             7006             Bay St / College St (East Side)
# 132120             7006             Bay St / College St (East Side)
# 132121             7057                 Simcoe St / Wellington St W
# 132122             7014  Sherbourne St / Carlton St (Allan Gardens)
#
#         to_station_id                to_station_name user_type
# 0                7089           Church St  / Wood St    Member
# 1                7154        Bathurst Subway Station    Member
# 2                7199      College St W / Markham St    Member
# 3                7010        King St W / Spadina Ave    Member
# 4                7047  University Ave / Gerrard St W    Member
# ...               ...                            ...       ...
# 132118           7017       Widmer St / Adelaide St     Member
# 132119           7066   Willcocks St / St. George St    Member
# 132120           7066   Willcocks St / St. George St    Member
# 132121           7023       College St W / Borden St    Member
# 132122           7113   Parliament St / Aberdeen Ave    Member
#
# [261148 rows x 9 columns]
#         trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0       1253914      7/1/2017 0:00      7/1/2017 0:15                    910
# 1       1253915      7/1/2017 0:01      7/1/2017 0:15                    837
# 2       1253916      7/1/2017 0:01      7/1/2017 0:14                    786
# 3       1253917      7/1/2017 0:01      7/1/2017 0:25                   1420
# 4       1253918      7/1/2017 0:01      7/1/2017 0:25                   1437
# ...         ...                ...                ...                    ...
# 363398  2383640  12/31/17 23:37:43  12/31/17 23:43:00                    317
# 363399  2383641  12/31/17 23:42:06  12/31/17 23:58:24                    978
# 363401  2383643  12/31/17 23:47:13   1/01/18 00:11:40                   1467
# 363402  2383644  12/31/17 23:47:40  12/31/17 23:57:49                    609
# 363404  2383646  12/31/17 23:49:41  12/31/17 23:57:41                    480
#
#                               from_station_name             to_station_name  \
# 0                   Princess St / Adelaide St E         424 Wellington St W
# 1                 Fort York  Blvd / Capreol Crt    HTO Park (Queens Quay W)
# 2                 Fort York  Blvd / Capreol Crt    HTO Park (Queens Quay W)
# 3       Elizabeth St / Edward St (Bus Terminal)     Boston Ave / Queen St E
# 4       Elizabeth St / Edward St (Bus Terminal)     Boston Ave / Queen St E
# ...                                         ...                         ...
# 363398               Ossington Ave / Bloor St W  Ossington Ave / College St
# 363399  Elizabeth St / Edward St (Bus Terminal)      Roxton Rd / College St
# 363401                 Bloor St / Brunswick Ave    HTO Park (Queens Quay W)
# 363402                  Kendal Ave / Spadina Rd    Augusta Ave / Denison Sq
# 363404                  Phoebe St / Spadina Ave      Simcoe St / Queen St W
#
#        user_type
# 0         Member
# 1         Casual
# 2         Casual
# 3         Casual
# 4         Casual
# ...          ...
# 363398    Member
# 363399    Member
# 363401    Casual
# 363402    Member
# 363404    Member
#
# [966993 rows x 7 columns]

# %%
bike_notreturned_2017 = bike_notreturned_2017_1.shape[0] + bike_notreturned_2017_2.shape[0]
bike_notreturned_2017
# Out:
# 1228141

# %%
bikeshare_2017 = {'Total Bikeshare Returned': bike_returned_2017, 'Total Bikeshare Not Returned': bike_notreturned_2017}
df3 = pd.DataFrame(data=bikeshare_2017,index=['Bikeshare 2017'])
df3
# Out:
#                 Total Bikeshare Returned  Total Bikeshare Not Returned
# Bikeshare 2017                     62998                       1228141

# %%
labels = ['Returned','Not Returned']
sizes = [bike_returned_2017,bike_notreturned_2017]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax.set_title('Bikeshare Return Rate 2017')


plt.show()

# %% [markdown]
# > Question No.2 : How many bikeshare trips usually visit more than just start/end points, but visited some other points before the end of the day?

# %% [markdown]
# Now we can assume if each trip id use more time than the average trip duration then the trip visited more than one point, so we need to find every single bikeshare trip which have trip duration greater than average trip duration in each day.

# %%
def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_1072d4c063164370a50a918430413880 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='dI3tJSJbm6qzDzVhirVofNikyMBsfPNkE34FROriwB4L',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q1).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q1 = pd.read_csv(body)

# %%
body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q2).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q2 = pd.read_csv(body)

# %%
body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q3).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q3 = pd.read_csv(body)

# %%
body = client_1072d4c063164370a50a918430413880.get_object(Bucket='bikesharetorontotask-donotdelete-pr-qnnodv3eyvfi6j',Key='Bikeshare Ridership (2017 Q4).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

q4 = pd.read_csv(body)

# %% [markdown]
# Because we want to find how many bikeshare trips usually visited some other points, we need to convert the time feature in pandas data frame. Below we will convert trip_start_time column into pandas datetime type so we can clasify the row into day value like monday, tuesday, wednesday, and so on.

# %%
q1['trip_start_time']=pd.to_datetime(q1['trip_start_time'])
q2['trip_start_time']=pd.to_datetime(q2['trip_start_time'])
q3['trip_start_time']=pd.to_datetime(q3['trip_start_time'])
q4['trip_start_time']=pd.to_datetime(q4['trip_start_time'])

# %%
bikeshare2017 = pd.concat([q1,q2,q3,q4])
bikeshare2017.drop(columns={'trip_stop_time'},inplace=True)
bikeshare2017
# Out:
#         trip_id     trip_start_time  trip_duration_seconds  from_station_id  \
# 0        712382 2017-01-01 00:00:00                  223.0           7051.0
# 1        712383 2017-01-01 00:00:00                  279.0           7143.0
# 2        712384 2017-01-01 00:05:00                 1394.0           7113.0
# 3        712385 2017-01-01 00:07:00                  826.0           7077.0
# 4        712386 2017-01-01 00:08:00                  279.0           7079.0
# ...         ...                 ...                    ...              ...
# 363400  2383642 2017-12-31 23:46:27                   26.0              NaN
# 363401  2383643 2017-12-31 23:47:13                 1467.0              NaN
# 363402  2383644 2017-12-31 23:47:40                  609.0              NaN
# 363403  2383645 2017-12-31 23:49:08                   26.0              NaN
# 363404  2383646 2017-12-31 23:49:41                  480.0              NaN
#
#                         from_station_name  to_station_id  \
# 0       Wellesley St E / Yonge St Green P         7089.0
# 1                Kendal Ave / Bernard Ave         7154.0
# 2            Parliament St / Aberdeen Ave         7199.0
# 3                      College Park South         7010.0
# 4                   McGill St / Church St         7047.0
# ...                                   ...            ...
# 363400           Bloor St / Brunswick Ave            NaN
# 363401           Bloor St / Brunswick Ave            NaN
# 363402            Kendal Ave / Spadina Rd            NaN
# 363403            Phoebe St / Spadina Ave            NaN
# 363404            Phoebe St / Spadina Ave            NaN
#
#                       to_station_name user_type
# 0                Church St  / Wood St    Member
# 1             Bathurst Subway Station    Member
# 2           College St W / Markham St    Member
# 3             King St W / Spadina Ave    Member
# 4       University Ave / Gerrard St W    Member
# ...                               ...       ...
# 363400       Bloor St / Brunswick Ave    Casual
# 363401       HTO Park (Queens Quay W)    Casual
# 363402       Augusta Ave / Denison Sq    Member
# 363403        Phoebe St / Spadina Ave    Member
# 363404         Simcoe St / Queen St W    Member
#
# [1355168 rows x 8 columns]

# %%
bikeshare2017['weekday_start'] = bikeshare2017['trip_start_time'].apply(lambda time: time.dayofweek)

# %%
day = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
bikeshare2017['weekday_start'] = bikeshare2017['weekday_start'].map(day)
bikeshare2017
# Out:
#         trip_id     trip_start_time  trip_duration_seconds  from_station_id  \
# 0        712382 2017-01-01 00:00:00                  223.0           7051.0
# 1        712383 2017-01-01 00:00:00                  279.0           7143.0
# 2        712384 2017-01-01 00:05:00                 1394.0           7113.0
# 3        712385 2017-01-01 00:07:00                  826.0           7077.0
# 4        712386 2017-01-01 00:08:00                  279.0           7079.0
# ...         ...                 ...                    ...              ...
# 363400  2383642 2017-12-31 23:46:27                   26.0              NaN
# 363401  2383643 2017-12-31 23:47:13                 1467.0              NaN
# 363402  2383644 2017-12-31 23:47:40                  609.0              NaN
# 363403  2383645 2017-12-31 23:49:08                   26.0              NaN
# 363404  2383646 2017-12-31 23:49:41                  480.0              NaN
#
#                         from_station_name  to_station_id  \
# 0       Wellesley St E / Yonge St Green P         7089.0
# 1                Kendal Ave / Bernard Ave         7154.0
# 2            Parliament St / Aberdeen Ave         7199.0
# 3                      College Park South         7010.0
# 4                   McGill St / Church St         7047.0
# ...                                   ...            ...
# 363400           Bloor St / Brunswick Ave            NaN
# 363401           Bloor St / Brunswick Ave            NaN
# 363402            Kendal Ave / Spadina Rd            NaN
# 363403            Phoebe St / Spadina Ave            NaN
# 363404            Phoebe St / Spadina Ave            NaN
#
#                       to_station_name user_type weekday_start
# 0                Church St  / Wood St    Member           Sun
# 1             Bathurst Subway Station    Member           Sun
# 2           College St W / Markham St    Member           Sun
# 3             King St W / Spadina Ave    Member           Sun
# 4       University Ave / Gerrard St W    Member           Sun
# ...                               ...       ...           ...
# 363400       Bloor St / Brunswick Ave    Casual           Sun
# 363401       HTO Park (Queens Quay W)    Casual           Sun
# 363402       Augusta Ave / Denison Sq    Member           Sun
# 363403        Phoebe St / Spadina Ave    Member           Sun
# 363404         Simcoe St / Queen St W    Member           Sun
#
# [1355168 rows x 9 columns]

# %% [markdown]
# Now we have the feature of day in the dataset. since we want to analyze how much bikeshare trip visited more than one point in a day using comparison between trip duration second each trip, so we could drop every column than unusefull for this. we just need column weekday_start and trip_duration_seconds
#
# ---

# %%
bikeshare2017[['weekday_start','trip_duration_seconds']]
bikeshare2017.set_index(keys='weekday_start',drop=True,inplace=True)
bikeshare2017
# Out:
#                trip_id     trip_start_time  trip_duration_seconds  \
# weekday_start
# Sun             712382 2017-01-01 00:00:00                  223.0
# Sun             712383 2017-01-01 00:00:00                  279.0
# Sun             712384 2017-01-01 00:05:00                 1394.0
# Sun             712385 2017-01-01 00:07:00                  826.0
# Sun             712386 2017-01-01 00:08:00                  279.0
# ...                ...                 ...                    ...
# Sun            2383642 2017-12-31 23:46:27                   26.0
# Sun            2383643 2017-12-31 23:47:13                 1467.0
# Sun            2383644 2017-12-31 23:47:40                  609.0
# Sun            2383645 2017-12-31 23:49:08                   26.0
# Sun            2383646 2017-12-31 23:49:41                  480.0
#
#                from_station_id                  from_station_name  \
# weekday_start
# Sun                     7051.0  Wellesley St E / Yonge St Green P
# Sun                     7143.0           Kendal Ave / Bernard Ave
# Sun                     7113.0       Parliament St / Aberdeen Ave
# Sun                     7077.0                 College Park South
# Sun                     7079.0              McGill St / Church St
# ...                        ...                                ...
# Sun                        NaN           Bloor St / Brunswick Ave
# Sun                        NaN           Bloor St / Brunswick Ave
# Sun                        NaN            Kendal Ave / Spadina Rd
# Sun                        NaN            Phoebe St / Spadina Ave
# Sun                        NaN            Phoebe St / Spadina Ave
#
#                to_station_id                to_station_name user_type
# weekday_start
# Sun                   7089.0           Church St  / Wood St    Member
# Sun                   7154.0        Bathurst Subway Station    Member
# Sun                   7199.0      College St W / Markham St    Member
# Sun                   7010.0        King St W / Spadina Ave    Member
# Sun                   7047.0  University Ave / Gerrard St W    Member
# ...                      ...                            ...       ...
# Sun                      NaN       Bloor St / Brunswick Ave    Casual
# Sun                      NaN       HTO Park (Queens Quay W)    Casual
# Sun                      NaN       Augusta Ave / Denison Sq    Member
# Sun                      NaN        Phoebe St / Spadina Ave    Member
# Sun                      NaN         Simcoe St / Queen St W    Member
#
# [1355168 rows x 8 columns]

# %% [markdown]
# Now we have tremendous and big data set in this notebook, we will separate them into 7 dataframe which represent each day in weeks. each data frame has information such day and trip duration in second.

# %%
sun = bikeshare2017['trip_duration_seconds']['Sun']
mon = bikeshare2017['trip_duration_seconds']['Mon']
tue = bikeshare2017['trip_duration_seconds']['Tue']
wed = bikeshare2017['trip_duration_seconds']['Wed']
thu = bikeshare2017['trip_duration_seconds']['Thu']
fri = bikeshare2017['trip_duration_seconds']['Fri']
sat = bikeshare2017['trip_duration_seconds']['Sat']

# %%
data_sun = pd.DataFrame(data=sun)
data_mon = pd.DataFrame(data=mon)
data_tue = pd.DataFrame(data=tue)
data_wed = pd.DataFrame(data=wed)
data_thu = pd.DataFrame(data=thu)
data_fri = pd.DataFrame(data=fri)
data_sat = pd.DataFrame(data=sat)

# %% [markdown]
# Now we will do a simple selection. we will select data include trip duration in second which larger than the average/mean trip duration in every different day.
# First we will do selection for sunday

# %%
print(data_sun['trip_duration_seconds'].mean())
visit_more_point_sun = data_sun.loc[data_sun['trip_duration_seconds']>=data_sun['trip_duration_seconds'].mean()]
display(visit_more_point_sun)
# Out:
# 1392.7523282278403
#      trip_duration_seconds
# Sun                 1394.0
# Sun                 1702.0
# Sun                 1801.0
# Sun                 1793.0
# Sun                 1403.0
# ..                     ...
# Sun                 2243.0
# Sun                 1555.0
# Sun                 1531.0
# Sun                 1431.0
# Sun                 1467.0
#
# [32063 rows x 1 columns]

# %% [markdown]
# Second, we will do selection for tuesday. and so on till monday

# %%
print(data_mon['trip_duration_seconds'].mean())
visit_more_point_mon = data_mon.loc[data_mon['trip_duration_seconds']>=data_mon['trip_duration_seconds'].mean()]
display(visit_more_point_mon)
# Out:
# 990.532267403472
#      trip_duration_seconds
# Mon                 1392.0
# Mon                 1191.0
# Mon                 1170.0
# Mon                 1096.0
# Mon                 1134.0
# ..                     ...
# Mon                 6971.0
# Mon                 1140.0
# Mon                 1177.0
# Mon                 1105.0
# Mon                 1243.0
#
# [49696 rows x 1 columns]

# %%
print(data_tue['trip_duration_seconds'].mean())
visit_more_point_tue = data_tue.loc[data_tue['trip_duration_seconds']>=data_tue['trip_duration_seconds'].mean()]
display(visit_more_point_tue)
# Out:
# 885.8438352512129
#      trip_duration_seconds
# Tue                  937.0
# Tue                  969.0
# Tue                 1069.0
# Tue                 1024.0
# Tue                 6755.0
# ..                     ...
# Tue                 1522.0
# Tue                 1428.0
# Tue                 1088.0
# Tue                  951.0
# Tue                 1134.0
#
# [59646 rows x 1 columns]

# %%
print(data_wed['trip_duration_seconds'].mean())
visit_more_point_wed = data_wed.loc[data_wed['trip_duration_seconds']>=data_wed['trip_duration_seconds'].mean()]
display(visit_more_point_wed)
# Out:
# 883.683700221489
#      trip_duration_seconds
# Wed                  989.0
# Wed                 1214.0
# Wed                 1473.0
# Wed                 1453.0
# Wed                 1344.0
# ..                     ...
# Wed                 1125.0
# Wed                 1125.0
# Wed                 1106.0
# Wed                  984.0
# Wed                  990.0
#
# [66592 rows x 1 columns]

# %%
print(data_thu['trip_duration_seconds'].mean())
visit_more_point_thu = data_thu.loc[data_thu['trip_duration_seconds']>=data_thu['trip_duration_seconds'].mean()]
display(visit_more_point_thu)
# Out:
# 876.53597021109
#      trip_duration_seconds
# Thu                  953.0
# Thu                  879.0
# Thu                  947.0
# Thu                  888.0
# Thu                  991.0
# ..                     ...
# Thu                  964.0
# Thu                 1128.0
# Thu                 1725.0
# Thu                  931.0
# Thu                 1213.0
#
# [54741 rows x 1 columns]

# %%
print(data_fri['trip_duration_seconds'].mean())
visit_more_point_fri = data_fri.loc[data_fri['trip_duration_seconds']>=data_fri['trip_duration_seconds'].mean()]
display(visit_more_point_fri)
# Out:
# 909.9927030873106
#      trip_duration_seconds
# Fri                 1046.0
# Fri                 1265.0
# Fri                  998.0
# Fri                 4252.0
# Fri                 1826.0
# ..                     ...
# Fri                 1043.0
# Fri                 1084.0
# Fri                 2052.0
# Fri                 1120.0
# Fri                  963.0
#
# [54522 rows x 1 columns]

# %%
print(data_sat['trip_duration_seconds'].mean())
visit_more_point_sat = data_sat.loc[data_sat['trip_duration_seconds']>=data_sat['trip_duration_seconds'].mean()]
display(visit_more_point_sat)
# Out:
# 1334.6012941762071
#      trip_duration_seconds
# Sat                 1376.0
# Sat                 1721.0
# Sat                 1560.0
# Sat                 1409.0
# Sat                 1353.0
# ..                     ...
# Sat                 1910.0
# Sat                 1338.0
# Sat                 1354.0
# Sat                 1582.0
# Sat                 1829.0
#
# [36135 rows x 1 columns]

# %%
visit_more_point_all = pd.concat([visit_more_point_mon,visit_more_point_tue,visit_more_point_wed,visit_more_point_thu,
                                  visit_more_point_fri,visit_more_point_fri,visit_more_point_sat,visit_more_point_sun])
display(visit_more_point_all)
print(visit_more_point_all.shape)
# Out:
#      trip_duration_seconds
# Mon                 1392.0
# Mon                 1191.0
# Mon                 1170.0
# Mon                 1096.0
# Mon                 1134.0
# ..                     ...
# Sun                 2243.0
# Sun                 1555.0
# Sun                 1531.0
# Sun                 1431.0
# Sun                 1467.0
#
# [407917 rows x 1 columns]
# (407917, 1)

# %% [markdown]
# Last, we will make data frame contains days in a week and bikeshare whch visitted some other point.

# %%
visit_more_point_day = {'Bikeshare visit some other point':(visit_more_point_mon.shape[0], visit_more_point_tue.shape[0], visit_more_point_wed.shape[0], visit_more_point_thu.shape[0], visit_more_point_fri.shape[0], visit_more_point_sat.shape[0], visit_more_point_sun.shape[0])}

# %%
index = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

# %%
df = pd.DataFrame(data=visit_more_point_day,index=index)
df
# Out:
#            Bikeshare visit some other point
# Monday                                49696
# Tuesday                               59646
# Wednesday                             66592
# Thursday                              54741
# Friday                                54522
# Saturday                              36135
# Sunday                                32063

# %%
df.plot(kind='bar')

# %%
labels = index
sizes = visit_more_point_mon.shape[0],visit_more_point_tue.shape[0],visit_more_point_wed.shape[0],visit_more_point_thu.shape[0],visit_more_point_fri.shape[0],visit_more_point_sat.shape[0],visit_more_point_sun.shape[0]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax.set_title('Bikeshare visited some other point')


plt.show()
